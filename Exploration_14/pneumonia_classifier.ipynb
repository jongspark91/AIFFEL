# %% [markdown]
# # Imports

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 48

print(ROOT_PATH)
# Out:
# /home/aiffel-dj53/aiffel

# %% [markdown]
# # 1. Data

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1082
# Pneumonia images count in training set: 3103

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# ## 데이터셋 갯수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# ## 라벨 확인

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %% [markdown]
# ## 라벨 데이터 생성 함수

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 2. 데이터 시각화

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 3. CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.93
# Weight for class 1: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/48
# 261/261 [==============================] - 23s 88ms/step - loss: 0.4417 - accuracy: 0.7708 - precision: 0.9469 - recall: 0.7318 - val_loss: 0.5676 - val_accuracy: 0.7452 - val_precision: 0.7452 - val_recall: 1.0000
# Epoch 2/48
# 261/261 [==============================] - 23s 86ms/step - loss: 0.2398 - accuracy: 0.9009 - precision: 0.9709 - recall: 0.8932 - val_loss: 0.8190 - val_accuracy: 0.7433 - val_precision: 0.7433 - val_recall: 1.0000
# Epoch 3/48
# 261/261 [==============================] - 23s 89ms/step - loss: 0.2104 - accuracy: 0.9183 - precision: 0.9758 - recall: 0.9124 - val_loss: 0.2943 - val_accuracy: 0.8596 - val_precision: 0.8411 - val_recall: 1.0000
# Epoch 4/48
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1469 - accuracy: 0.9430 - precision: 0.9828 - recall: 0.9396 - val_loss: 0.1028 - val_accuracy: 0.9577 - val_precision: 0.9867 - val_recall: 0.9561
# Epoch 5/48
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1555 - accuracy: 0.9397 - precision: 0.9833 - recall: 0.9343 - val_loss: 0.0786 - val_accuracy: 0.9712 - val_precision: 0.9882 - val_recall: 0.9729
# Epoch 6/48
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1619 - accuracy: 0.9389 - precision: 0.9814 - recall: 0.9355 - val_loss: 0.2064 - val_accuracy: 0.9144 - val_precision: 0.9986 - val_recall: 0.8867
# Epoch 7/48
# 261/261 [==============================] - 25s 94ms/step - loss: 0.1371 - accuracy: 0.9485 - precision: 0.9875 - recall: 0.9426 - val_loss: 0.3211 - val_accuracy: 0.8606 - val_precision: 0.8422 - val_recall: 1.0000
# Epoch 8/48
# 261/261 [==============================] - 24s 94ms/step - loss: 0.1302 - accuracy: 0.9507 - precision: 0.9859 - recall: 0.9471 - val_loss: 0.0739 - val_accuracy: 0.9712 - val_precision: 0.9987 - val_recall: 0.9626
# Epoch 9/48
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1082 - accuracy: 0.9607 - precision: 0.9893 - recall: 0.9574 - val_loss: 0.0720 - val_accuracy: 0.9740 - val_precision: 0.9795 - val_recall: 0.9858
# Epoch 10/48
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1228 - accuracy: 0.9519 - precision: 0.9859 - recall: 0.9486 - val_loss: 0.5191 - val_accuracy: 0.8317 - val_precision: 1.0000 - val_recall: 0.7739
# Epoch 11/48
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1116 - accuracy: 0.9535 - precision: 0.9869 - recall: 0.9499 - val_loss: 0.0615 - val_accuracy: 0.9779 - val_precision: 0.9820 - val_recall: 0.9884
# Epoch 12/48
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1057 - accuracy: 0.9602 - precision: 0.9880 - recall: 0.9581 - val_loss: 0.0751 - val_accuracy: 0.9692 - val_precision: 0.9882 - val_recall: 0.9703
# Epoch 13/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.1125 - accuracy: 0.9593 - precision: 0.9887 - recall: 0.9561 - val_loss: 0.0656 - val_accuracy: 0.9798 - val_precision: 0.9858 - val_recall: 0.9871
# Epoch 14/48
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0972 - accuracy: 0.9667 - precision: 0.9917 - recall: 0.9631 - val_loss: 0.1495 - val_accuracy: 0.9375 - val_precision: 0.9972 - val_recall: 0.9185
# Epoch 15/48
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0949 - accuracy: 0.9643 - precision: 0.9920 - recall: 0.9596 - val_loss: 0.1129 - val_accuracy: 0.9558 - val_precision: 0.9986 - val_recall: 0.9419
# Epoch 16/48
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1246 - accuracy: 0.9502 - precision: 0.9859 - recall: 0.9465 - val_loss: 0.2524 - val_accuracy: 0.9183 - val_precision: 0.9971 - val_recall: 0.8928
# Epoch 17/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.1054 - accuracy: 0.9598 - precision: 0.9899 - recall: 0.9554 - val_loss: 0.1009 - val_accuracy: 0.9615 - val_precision: 0.9646 - val_recall: 0.9845
# Epoch 18/48
# 261/261 [==============================] - 26s 101ms/step - loss: 0.0975 - accuracy: 0.9638 - precision: 0.9914 - recall: 0.9598 - val_loss: 0.0618 - val_accuracy: 0.9731 - val_precision: 0.9960 - val_recall: 0.9677
# Epoch 19/48
# 261/261 [==============================] - 26s 98ms/step - loss: 0.0802 - accuracy: 0.9727 - precision: 0.9943 - recall: 0.9686 - val_loss: 0.2280 - val_accuracy: 0.9135 - val_precision: 1.0000 - val_recall: 0.8839
# Epoch 20/48
# 261/261 [==============================] - 27s 102ms/step - loss: 0.0979 - accuracy: 0.9643 - precision: 0.9913 - recall: 0.9602 - val_loss: 0.0725 - val_accuracy: 0.9692 - val_precision: 0.9934 - val_recall: 0.9652
# Epoch 21/48
# 261/261 [==============================] - 25s 98ms/step - loss: 0.0830 - accuracy: 0.9698 - precision: 0.9933 - recall: 0.9657 - val_loss: 0.3196 - val_accuracy: 0.8865 - val_precision: 0.9985 - val_recall: 0.8492
# Epoch 22/48
# 261/261 [==============================] - 25s 97ms/step - loss: 0.0860 - accuracy: 0.9648 - precision: 0.9917 - recall: 0.9608 - val_loss: 0.1016 - val_accuracy: 0.9558 - val_precision: 0.9973 - val_recall: 0.9432
# Epoch 23/48
# 261/261 [==============================] - 26s 98ms/step - loss: 0.0733 - accuracy: 0.9741 - precision: 0.9941 - recall: 0.9710 - val_loss: 0.1501 - val_accuracy: 0.9394 - val_precision: 0.9944 - val_recall: 0.9239
# Epoch 24/48
# 261/261 [==============================] - 26s 99ms/step - loss: 0.0848 - accuracy: 0.9701 - precision: 0.9920 - recall: 0.9673 - val_loss: 0.0551 - val_accuracy: 0.9779 - val_precision: 0.9908 - val_recall: 0.9793
# Epoch 25/48
# 261/261 [==============================] - 25s 95ms/step - loss: 0.0629 - accuracy: 0.9782 - precision: 0.9951 - recall: 0.9755 - val_loss: 0.0696 - val_accuracy: 0.9788 - val_precision: 0.9870 - val_recall: 0.9845
# Epoch 26/48
# 261/261 [==============================] - 25s 95ms/step - loss: 0.0855 - accuracy: 0.9677 - precision: 0.9930 - recall: 0.9632 - val_loss: 1.3489 - val_accuracy: 0.8808 - val_precision: 0.9011 - val_recall: 0.9431
# Epoch 27/48
# 261/261 [==============================] - 25s 95ms/step - loss: 0.0833 - accuracy: 0.9665 - precision: 0.9940 - recall: 0.9606 - val_loss: 0.0510 - val_accuracy: 0.9779 - val_precision: 0.9908 - val_recall: 0.9793
# Epoch 28/48
# 261/261 [==============================] - 25s 95ms/step - loss: 0.0686 - accuracy: 0.9765 - precision: 0.9944 - recall: 0.9738 - val_loss: 0.2311 - val_accuracy: 0.9240 - val_precision: 0.9093 - val_recall: 0.9974
# Epoch 29/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.0603 - accuracy: 0.9765 - precision: 0.9938 - recall: 0.9746 - val_loss: 0.0812 - val_accuracy: 0.9731 - val_precision: 0.9794 - val_recall: 0.9845
# Epoch 30/48
# 261/261 [==============================] - 25s 95ms/step - loss: 0.0626 - accuracy: 0.9768 - precision: 0.9960 - recall: 0.9726 - val_loss: 0.0618 - val_accuracy: 0.9760 - val_precision: 0.9921 - val_recall: 0.9755
# Epoch 31/48
# 261/261 [==============================] - 25s 94ms/step - loss: 0.0555 - accuracy: 0.9796 - precision: 0.9951 - recall: 0.9774 - val_loss: 0.0525 - val_accuracy: 0.9798 - val_precision: 0.9961 - val_recall: 0.9768
# Epoch 32/48
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0373 - accuracy: 0.9875 - precision: 0.9977 - recall: 0.9854 - val_loss: 0.1086 - val_accuracy: 0.9577 - val_precision: 0.9986 - val_recall: 0.9444
# Epoch 33/48
# 261/261 [==============================] - 24s 92ms/step - loss: 0.0588 - accuracy: 0.9758 - precision: 0.9941 - recall: 0.9732 - val_loss: 0.0590 - val_accuracy: 0.9769 - val_precision: 0.9960 - val_recall: 0.9729
# Epoch 34/48
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0461 - accuracy: 0.9835 - precision: 0.9977 - recall: 0.9801 - val_loss: 0.0494 - val_accuracy: 0.9769 - val_precision: 0.9947 - val_recall: 0.9742
# Epoch 35/48
# 261/261 [==============================] - 24s 92ms/step - loss: 0.0375 - accuracy: 0.9873 - precision: 0.9974 - recall: 0.9854 - val_loss: 0.1045 - val_accuracy: 0.9625 - val_precision: 0.9973 - val_recall: 0.9522
# Epoch 36/48
# 261/261 [==============================] - 22s 86ms/step - loss: 0.0699 - accuracy: 0.9780 - precision: 0.9947 - recall: 0.9755 - val_loss: 0.0754 - val_accuracy: 0.9692 - val_precision: 0.9908 - val_recall: 0.9678
# Epoch 37/48
# 261/261 [==============================] - 24s 91ms/step - loss: 0.0352 - accuracy: 0.9871 - precision: 0.9977 - recall: 0.9848 - val_loss: 0.0859 - val_accuracy: 0.9683 - val_precision: 0.9987 - val_recall: 0.9587
# Epoch 38/48
# 261/261 [==============================] - 25s 94ms/step - loss: 0.0472 - accuracy: 0.9842 - precision: 0.9974 - recall: 0.9813 - val_loss: 0.1085 - val_accuracy: 0.9500 - val_precision: 0.9892 - val_recall: 0.9432
# Epoch 39/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.0415 - accuracy: 0.9830 - precision: 0.9970 - recall: 0.9799 - val_loss: 0.0534 - val_accuracy: 0.9808 - val_precision: 0.9948 - val_recall: 0.9794
# Epoch 40/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.0412 - accuracy: 0.9852 - precision: 0.9971 - recall: 0.9829 - val_loss: 0.0663 - val_accuracy: 0.9731 - val_precision: 0.9960 - val_recall: 0.9677
# Epoch 41/48
# 261/261 [==============================] - 24s 94ms/step - loss: 0.0344 - accuracy: 0.9885 - precision: 0.9971 - recall: 0.9874 - val_loss: 0.0907 - val_accuracy: 0.9673 - val_precision: 0.9987 - val_recall: 0.9575
# Epoch 42/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.0206 - accuracy: 0.9923 - precision: 0.9981 - recall: 0.9916 - val_loss: 0.0467 - val_accuracy: 0.9808 - val_precision: 0.9961 - val_recall: 0.9781
# Epoch 43/48
# 261/261 [==============================] - 24s 92ms/step - loss: 0.0245 - accuracy: 0.9921 - precision: 0.9980 - recall: 0.9913 - val_loss: 0.0848 - val_accuracy: 0.9692 - val_precision: 0.9920 - val_recall: 0.9664
# Epoch 44/48
# 261/261 [==============================] - 24s 91ms/step - loss: 0.0193 - accuracy: 0.9943 - precision: 0.9993 - recall: 0.9929 - val_loss: 0.0449 - val_accuracy: 0.9894 - val_precision: 0.9935 - val_recall: 0.9923
# Epoch 45/48
# 261/261 [==============================] - 25s 94ms/step - loss: 0.0413 - accuracy: 0.9895 - precision: 0.9974 - recall: 0.9884 - val_loss: 0.0861 - val_accuracy: 0.9702 - val_precision: 0.9960 - val_recall: 0.9639
# Epoch 46/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.0360 - accuracy: 0.9861 - precision: 0.9964 - recall: 0.9848 - val_loss: 0.0700 - val_accuracy: 0.9817 - val_precision: 0.9948 - val_recall: 0.9806
# Epoch 47/48
# 261/261 [==============================] - 25s 94ms/step - loss: 0.0436 - accuracy: 0.9844 - precision: 0.9957 - recall: 0.9832 - val_loss: 0.0516 - val_accuracy: 0.9865 - val_precision: 0.9910 - val_recall: 0.9910
# Epoch 48/48
# 261/261 [==============================] - 24s 93ms/step - loss: 0.0147 - accuracy: 0.9957 - precision: 0.9987 - recall: 0.9955 - val_loss: 0.0582 - val_accuracy: 0.9846 - val_precision: 0.9948 - val_recall: 0.9845

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### ㄴ 여러번의 Epochs를 시행해봤는데 48Epochs정도의 구간에서 train과 validation이 수렴하여 48로 책정했다.

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 59ms/step - loss: 1.5115 - accuracy: 0.8093 - precision: 0.7694 - recall: 0.9923
